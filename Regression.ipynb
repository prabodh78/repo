# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data.head()
# Out:
#       2,0.873112136,,
# 0  2.04,0.877491752,,
# 1  2.21,0.871571418,,
# 2  2.38,0.948997436,,
# 3  2.46,0.895847669,,
# 4  2.54,0.951908326,,

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data1=pd.read_csv("K_meansHW_TomMitchell_data1.csv",names=['var1','var2'])
data2=pd.read_csv("K_meansHW_TomMitchell_data2.csv",names=['var3','var4'])

###data1.head()
###data2.head()

# %matplotlib inline 
plt.scatter(data1.var1,data1.var2,c='red')
plt.scatter(data2.var3,data2.var4,c='blue')
plt.show()
